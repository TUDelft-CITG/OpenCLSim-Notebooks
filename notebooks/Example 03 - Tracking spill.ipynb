# %% [markdown]
# ## Example 03 - Tracking Spill

# %% [markdown]
# **Example description:** Example of a project where sediment spill limits influence project progress.

# %% [markdown]
# * [**0. Import required libraries:**](#0.-Import-required-libraries)<br>
# * [**1. Define work method:**](#1.-Define-work-method)<br>
#    * [**1.1 Sites:**](#1.1-Define-the-project-sites)<br>
#    * [**1.2 Equipment:**](#1.2-Define-the-project-equipment)<br>
#    * [**1.3 Activities:**](#1.3-Define-the-activity)<br>
# * [**2. Run the simulation:**](#2.-Run-the-simulation)<br>
# * [**3. Post processing:**](#3.-Postprocessing)<br>

# %% [markdown]
# ## 0. Import required libraries

# %%
import openclsim
print('This notebook has been tested with OpenCLSim version {}'.format(openclsim.__version__))
# Out:
# This notebook has been tested with OpenCLSim version 1.2.3

# %%
# package(s) related to time, space and id
import datetime, time
import platform

# you need these dependencies (you can get these from anaconda)
# package(s) related to the simulation
import simpy

# spatial libraries 
import shapely.geometry
from simplekml import Kml, Style

# package(s) for data handling
import numpy as np

# digital twin package
import openclsim.core as core
import openclsim.model as model
import openclsim.plot as plot

# Additional import to save the initialization of the simulation
import openclsim.savesim as savesim

# %%
# Create simulation environment
simulation_start = datetime.datetime(2019, 1, 1)

my_env = simpy.Environment(initial_time = time.mktime(simulation_start.timetuple()))
my_env.epoch = time.mktime(simulation_start.timetuple())

# %% [markdown]
# ## 1. Define work method

# %% [markdown]
# ### 1.1 Define the project sites
# You can specify a project site object by entering mix-ins:
#
#     core.Identifiable - enables you to give the object a name
#     core.Log - enables you to log all discrete events in which the object is involved
#     core.Locatable - enables you to add coordinates to extract distance information and visualize
#     core.HasContainer - enables you to add information on the material available at the site
#     core.HasResource - enables you to add information on serving equipment
#     core.HasWeather - enables you to add weather conditions
#     core.HasSpill - enables tracking of spill
#     core.HasSpillCondition - enable imposition of spill limits
#     core.HasSoil - enables book keeping of soil layers and soil information

# %% [markdown]
# #### First create objects with the desired properties

# %%
# The generic site class
Site = type('Site', (core.Identifiable,       # Give it a name
                     core.Log,                # Allow logging of all discrete events
                     core.Locatable,          # Add coordinates to extract distance information and visualize
                     core.HasContainer,       # Add information on the material available at the site
                     core.HasResource,        # Add information on serving equipment
                     core.HasSpill,           # Add tracking of spill
                     core.HasSpillCondition,  # Add limits
                     core.HasSoil),           # Add soil layers and information
            {})                               # The dictionary is empty because the site type is generic

# %% [markdown]
# #### Next specify the properties for sites you wish to create

# %%
# The spill conditions
start_1 = simulation_start                                    # condition 1 start as the simulation starts
end_1   = start_1 + datetime.timedelta(seconds = 14*24*3600)  # condition 1 lasts the first 2 weeks

start_2 = end_1                                               # condition 2 start as the simulation starts
end_2   = start_2 + datetime.timedelta(seconds = 14*24*3600)  # condition 2 lasts another 2 weeks

condition_1 = core.SpillCondition(5_000,             # Maximum kg of spill during period
                                  start_1,           # Start of period
                                  end_1)             # End of period

condition_2 = core.SpillCondition(5_500,             # Maximum kg of spill during period
                                  start_2,           # Start of period
                                  end_2)             # End of period

conditions = [condition_1, condition_2]

# %%
# The soil layers
layer_1 = core.SoilLayer(0, 100_000, "Clay", 1_400, 0.05) # layer, volume, type, density, percentage of fines
layer_2 = core.SoilLayer(1, 200_000, "Sand", 1_800, 0.3)  # layer, volume, type, density, percentage of fines
layer_3 = core.SoilLayer(2, 200_000, "Rock", 2_000, 0.0)  # layer, volume, type, density, percentage of fines

# %%
# Information on the extraction site - the "from site" - the "win locatie"
location_from_site = shapely.geometry.Point(4.18055556, 52.18664444)  # lon, lat

data_from_site = {"env": my_env,                                # The simpy environment defined in the first cel
                  "name": "Winlocatie",                         # The name of the site
                  "ID": "6dbbbdf4-4589-11e9-a501-b469212bff5b", # For logging purposes
                  "geometry": location_from_site,               # The coordinates of the project site
                  "capacity": 500_000,                          # The capacity of the site
                  "level": 500_000,                             # The actual volume of the site
                  "conditions": conditions}                     # Add the spill conditions

# %%
# Information on the dumping site - the "to site" - the "dump locatie"
location_to_site = shapely.geometry.Point(4.25222222, 52.11428333)     # lon, lat

data_to_site = {"env": my_env,                                # The simpy environment defined in the first cel
                "name": "Dumplocatie",                        # The name of the site
                "ID": "6dbbbdf5-4589-11e9-82b2-b469212bff5b", # For logging purposes
                "geometry": location_to_site,                 # The coordinates of the project site
                "capacity": 500_000,                          # The capacity of the site
                "level": 0,                                   # The actual volume of the site (empty of course)
                "conditions": conditions}                     # Add the spill conditions

# %% [markdown]
# #### Finally create specific instances of the predefined objects with the specified properties

# %%
# The two objects used for the simulation
from_site = Site(**data_from_site)
to_site   = Site(**data_to_site)

# Add soil information to the dredging site
from_site.add_layers(soillayers = [layer_2, layer_1, layer_3])

# %% [markdown]
# ### 1.2 Define the project equipment
# You can specify a vessel object by entering mix-ins:
#
#     core.Identifiable - enables you to give the object a name
#     core.Log - enables you to log all discrete events in which the object is involved
#     core.ContainerDependentMovable - s moving container, so capacity and location
#     core.Processor - allows for loading and unloading
#     core.HasResource - adds information on serving equipment
#     core.HasDepthRestriction - adds information on depth restriction
#     core.HasSoil - adds soil object, because it moves soil
#     core.HasPlume - initializes spill terms

# %% [markdown]
# #### First create objects with the desired properties

# %%
# The generic class for an object that can move and transport (a TSHD for example)
TransportProcessingResource = type('TransportProcessingResource', 
                                   (core.Identifiable,              # Give it a name
                                    core.Log,                       # Allow logging of all discrete events
                                    core.ContainerDependentMovable, # A moving container, so capacity and location
                                    core.Processor,                 # Allow for loading and unloading
                                    core.HasResource,               # Add information on serving equipment
                                    core.HasSoil,                   # Add soil object, because it moves soil
                                    core.HasPlume,                  # Initialize spill terms
                                    core.HasCosts,                  # Add information on costs
                                    core.LoadingFunction,           # Add a loading function
                                    core.UnloadingFunction,         # Add an unloading function
                                   ),
                                   {})

# %% [markdown]
# #### Next specify the properties for vessel(s) you wish to create

# %%
# For more realistic simulation you might want to have speed dependent on the volume carried by the vessel
def compute_v_provider(v_empty, v_full):
    return lambda x: x * (v_full - v_empty) + v_empty

# %%
# TSHD variables
data_hopper = {"env": my_env,                                       # The simpy environment 
               "name": "Hopper 01",                                 # Name
               "ID": "6dbbbdf6-4589-11e9-95a2-b469212bff5b",        # For logging purposes
               "geometry": location_from_site,                      # It starts at the "from site"
               "loading_rate": 1,                                   # Loading rate
               "unloading_rate": 1,                                 # Unloading rate
               "capacity": 5_000,                                   # Capacity of the hopper - "Beunvolume"
               "compute_v": compute_v_provider(5, 4.5),             # Variable speed 
               "weekrate": 700_000}

# %% [markdown]
# #### Finally create specific instances of the predefined objects with the specified properties

# %%
# The simulation object
hopper = TransportProcessingResource(**data_hopper)

# %% [markdown]
# ### 1.3 Define the activity

# %%
# Create activity
activity = model.Activity(env = my_env,           # The simpy environment defined in the first cel
                          name = "Soil movement", # We are moving soil
                          ID = "6dbbbdf7-4589-11e9-bf3b-b469212bff5b", # For logging purposes
                          origin = from_site,     # We originate from the from_site
                          destination = to_site,  # And therefore travel to the to_site
                          loader = hopper,        # The benefit of a TSHD, all steps can be done
                          mover = hopper,         # The benefit of a TSHD, all steps can be done
                          unloader = hopper,      # The benefit of a TSHD, all steps can be done
                          start_event = None,     # We can start right away
                          stop_event = None)      # We stop once there is nothing more to move

# %% [markdown]
# ### 2. Run the simulation

# %%
my_env.run()

print("")
print("*** Dredging project finished in {}".format(datetime.timedelta(seconds=int(my_env.now - my_env.epoch))))
print("*** Transport cost {:,.2f}€.".format(int(hopper.cost)))
# Out:
# *** Dredging project finished in 44 days, 3:49:55
# *** Transport cost 4,415,967.00€.

# %% [markdown]
# ### 3. Postprocessing

# %% [markdown]
# #### Vessel planning

# %%
vessels = [hopper]
activities = ['loading', 'unloading', 'sailing full', 'sailing empty', 'waiting for spill']
colors = {0:'rgb(55,126,184)', 1:'rgb(255,150,0)', 2:'rgb(98, 192, 122)', 3:'rgb(98, 141, 122)', 4:'rgb(255,0,0)'}

plot.vessel_planning(vessels, activities, colors)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>
#
#
#             <div id="58f9ec7f-2768-40bf-9822-5c4ac630b749" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("58f9ec7f-2768-40bf-9822-5c4ac630b749")) {
#                     Plotly.newPlot(
#                         '58f9ec7f-2768-40bf-9822-5c4ac630b749',
#                         [{"connectgaps": false, "hoverinfo": "y+name", "line": {"color": "rgb(55,126,184)", "width": 10}, "mode": "lines", "name": "loading", "type": "scatter", "x": ["2019-01-29T00:00:00", "2019-01-29T00:00:00", "2019-01-29T01:23:20", "2019-01-29T01:23:20", "2019-01-29T01:23:20", "2019-01-29T03:53:00.814941", "2019-01-29T03:53:00.814941", "2019-01-29T05:16:20.814941", "2019-01-29T05:16:20.814941", "2019-01-29T05:16:20.814941", "2019-01-29T07:46:01.629882", "2019-01-29T07:46:01.629882", "2019-01-29T09:09:21.629882", "2019-01-29T09:09:21.629882", "2019-01-29T09:09:21.629882", "2019-01-29T11:39:02.444823", "2019-01-29T11:39:02.444823", "2019-01-29T13:02:22.444823", "2019-01-29T13:02:22.444823", "2019-01-29T13:02:22.444823", "2019-01-29T15:32:03.259764", "2019-01-29T15:32:03.259764", "2019-01-29T16:55:23.259764", "2019-01-29T16:55:23.259764", "2019-01-29T16:55:23.259764", "2019-01-29T19:25:04.074705", "2019-01-29T19:25:04.074705", "2019-01-29T20:48:24.074705", "2019-01-29T20:48:24.074705", "2019-01-29T20:48:24.074705", "2019-01-29T23:18:04.889646", "2019-01-29T23:18:04.889646", "2019-01-30T00:41:24.889646", "2019-01-30T00:41:24.889646", "2019-01-30T00:41:24.889646", "2019-01-30T03:11:05.704587", "2019-01-30T03:11:05.704587", "2019-01-30T04:34:25.704587", "2019-01-30T04:34:25.704587", "2019-01-30T04:34:25.704587", "2019-01-30T07:04:06.519527", "2019-01-30T07:04:06.519527", "2019-01-30T08:27:26.519527", "2019-01-30T08:27:26.519527", "2019-01-30T08:27:26.519527", "2019-01-30T10:57:07.334468", "2019-01-30T10:57:07.334468", "2019-01-30T12:20:27.334468", "2019-01-30T12:20:27.334468", "2019-01-30T12:20:27.334468", "2019-01-30T14:50:08.149409", "2019-01-30T14:50:08.149409", "2019-01-30T16:13:28.149409", "2019-01-30T16:13:28.149409", "2019-01-30T16:13:28.149409", "2019-01-30T18:43:08.964350", "2019-01-30T18:43:08.964350", "2019-01-30T20:06:28.964350", "2019-01-30T20:06:28.964350", "2019-01-30T20:06:28.964350", "2019-01-30T22:36:09.779291", "2019-01-30T22:36:09.779291", "2019-01-30T23:59:29.779291", "2019-01-30T23:59:29.779291", "2019-01-30T23:59:29.779291", "2019-01-31T02:29:10.594232", "2019-01-31T02:29:10.594232", "2019-01-31T03:52:30.594232", "2019-01-31T03:52:30.594232", "2019-01-31T03:52:30.594232", "2019-01-31T06:22:11.409173", "2019-01-31T06:22:11.409173", "2019-01-31T07:45:31.409173", "2019-01-31T07:45:31.409173", "2019-01-31T07:45:31.409173", "2019-01-31T10:15:12.224114", "2019-01-31T10:15:12.224114", "2019-01-31T11:38:32.224114", "2019-01-31T11:38:32.224114", "2019-01-31T11:38:32.224114", "2019-01-31T14:08:13.039055", "2019-01-31T14:08:13.039055", "2019-01-31T15:31:33.039055", "2019-01-31T15:31:33.039055", "2019-01-31T15:31:33.039055", "2019-01-31T18:01:13.853996", "2019-01-31T18:01:13.853996", "2019-01-31T19:24:33.853996", "2019-01-31T19:24:33.853996", "2019-01-31T19:24:33.853996", "2019-01-31T21:54:14.668937", "2019-01-31T21:54:14.668937", "2019-01-31T23:17:34.668937", "2019-01-31T23:17:34.668937", "2019-01-31T23:17:34.668937", "2019-02-01T01:47:15.483878", "2019-02-01T01:47:15.483878", "2019-02-01T03:10:35.483878", "2019-02-01T03:10:35.483878", "2019-02-01T03:10:35.483878", "2019-02-01T05:40:16.298819", "2019-02-01T05:40:16.298819", "2019-02-01T07:03:36.298819", "2019-02-01T07:03:36.298819", "2019-02-01T07:03:36.298819", "2019-02-01T09:33:17.113760", "2019-02-01T09:33:17.113760", "2019-02-01T10:56:37.113760", "2019-02-01T10:56:37.113760", "2019-02-01T10:56:37.113760", "2019-02-01T13:26:17.928700", "2019-02-01T13:26:17.928700", "2019-02-01T14:49:37.928700", "2019-02-01T14:49:37.928700", "2019-02-01T14:49:37.928700", "2019-02-01T17:19:18.743641", "2019-02-01T17:19:18.743641", "2019-02-01T18:42:38.743641", "2019-02-01T18:42:38.743641", "2019-02-01T18:42:38.743641", "2019-02-01T21:12:19.558582", "2019-02-01T21:12:19.558582", "2019-02-01T22:35:39.558582", "2019-02-01T22:35:39.558582", "2019-02-01T22:35:39.558582", "2019-02-02T01:05:20.373523", "2019-02-02T01:05:20.373523", "2019-02-02T02:28:40.373523", "2019-02-02T ...

# %% [markdown]
# #### Some results

# %%
for container in from_site.SpillConditions["Spill limit"]:
    print(container.level)
# Out:
# 0
# 5250.0

# %%
from_site.soil
# Out:
# {'Layer 0000': {'Layer': 0,
#   'Volume': 0,
#   'Material': 'Clay',
#   'Density': 1400,
#   'Fines': 0.05},
#  'Layer 0001': {'Layer': 1,
#   'Volume': 0,
#   'Material': 'Sand',
#   'Density': 1800,
#   'Fines': 0.3},
#  'Layer 0002': {'Layer': 2,
#   'Volume': 0.0,
#   'Material': 'Rock',
#   'Density': 2000,
#   'Fines': 0.0}}

# %%
to_site.soil
# Out:
# {'Layer 0000': {'Layer': 0,
#   'Volume': 200000.0,
#   'Material': 'Mixture of: Rock',
#   'Density': 2000.0,
#   'Fines': 0.0},
#  'Layer 0001': {'Layer': 1,
#   'Volume': 200000.0,
#   'Material': 'Mixture of: Sand',
#   'Density': 1800.0,
#   'Fines': 0.3},
#  'Layer 0002': {'Layer': 2,
#   'Volume': 100000.0,
#   'Material': 'Mixture of: Clay',
#   'Density': 1400.0,
#   'Fines': 0.05}}

# %% [markdown]
# ### 4. Save all logs

# %%
sites = [from_site, to_site]
equipment = [hopper]
activities = [activity]

save = savesim.LogSaver(sites, equipment, activities, 
                        simulation_id = '0b5f6b0c-4591-11e9-9288-b469212bff5b', simulation_name = "Example 03",
                        location = "Simulation Results", overwrite = True)

save.save_all_logs()

# %%
save.unique_activities
# Out:
#                              ActivityID   ActivityName
# 0  6dbbbdf7-4589-11e9-bf3b-b469212bff5b  Soil movement
